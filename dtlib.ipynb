# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder, OrdinalEncoder
from sklearn.tree import DecisionTreeClassifier, plot_tree, export_text
import matplotlib.pyplot as plt
import numpy as np

df = pd.read_csv("Lipstick.csv")
df.drop("Id", axis=1, inplace=True)

# %%
X = df[["Age","Income", "Gender", "MaritalStatus"]]
Y = df["Buys"]

X_enc = OrdinalEncoder(dtype=np.int32).fit_transform(X)
Y_enc = LabelEncoder().fit_transform(Y)

# %%
clf = DecisionTreeClassifier(criterion="gini", random_state=0)
clf.fit(X_enc, Y_enc)
# Out:
# DecisionTreeClassifier(random_state=0)

# %%
plt.figure(figsize=(12,8))
plot_tree(clf, feature_names=X.columns)
plt.show()

# %%
test = [["<21", "Low", "Female", "Married"]]
test_enc = OrdinalEncoder(dtype=np.int32).fit_transform(test)

# %%
pred_enc = clf.predict(test_enc)
pred = le.inverse_transform(pred_enc)

# %%
print(pred)
# Out:
# ['Yes']

# %%
test = [[">35", "Medium", "Female", "Married"]]
test_enc = OrdinalEncoder(dtype=np.int32).fit_transform(test)

# %%
pred_enc = clf.predict(test_enc)
pred = le.inverse_transform(pred_enc)
print(pred)
# Out:
# ['Yes']

# %%
test = [["21-35", "Low", "Male", "Married"]]
test_enc = OrdinalEncoder(dtype=np.int32).fit_transform(test)

# %%
pred_enc = clf.predict(test_enc)
pred = le.inverse_transform(pred_enc)
print(pred)
# Out:
# ['Yes']
